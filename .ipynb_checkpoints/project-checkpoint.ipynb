# %%
# !pip install pandas numpy matplotlib scikit-learn

# %%
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\phuta\Downloads\ML_Project\ml_project_env\Scripts\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("financial_fraud_detection_dataset(1).csv")

# %%
df.columns
# Out:
# Index(['transaction_id', 'timestamp', 'sender_account', 'receiver_account',
#        'amount', 'transaction_type', 'merchant_category', 'location',
#        'device_used', 'is_fraud', 'fraud_type', 'time_since_last_transaction',
#        'spending_deviation_score', 'velocity_score', 'geo_anomaly_score',
#        'payment_channel', 'ip_address', 'device_hash'],
#       dtype='str')

# %%
df = df[["timestamp", "amount", "transaction_type"]]

# %%
df.columns = ["transaction_date", "amount", "transaction_type"]

# %%
df = df[["transaction_date", "amount", "transaction_type"]]

# %%
df["transaction_date"] = pd.to_datetime(df["transaction_date"], format="ISO8601")

# %%
df.head()
# Out:
#             transaction_date   amount transaction_type
# 0 2023-08-22 09:22:43.516168   343.78       withdrawal
# 1 2023-08-04 01:58:02.606711   419.65       withdrawal
# 2 2023-05-12 11:39:33.742963  2773.86          deposit
# 3 2023-10-10 06:04:43.195112  1666.22          deposit
# 4 2023-09-24 08:09:02.700162    24.43         transfer

# %%
df["deposit_amount"] = df["amount"].where(
    df["transaction_type"] == "deposit", 0
)

df["withdrawal_amount"] = df["amount"].where(
    df["transaction_type"].isin(["withdrawal", "payment"]), 0
)

# %%
df.columns
# Out:
# Index(['transaction_date', 'amount', 'transaction_type', 'deposit_amount',
#        'withdrawal_amount'],
#       dtype='str')

# %%
df = df[["transaction_date", "deposit_amount", "withdrawal_amount"]]

# %%
df = df.set_index("transaction_date")

# %%
monthly_df = df.resample("h").sum()

monthly_df.head()
# Out:
#                      deposit_amount  withdrawal_amount
# transaction_date
# 2023-01-01 00:00:00         8620.73            1828.63
# 2023-01-01 01:00:00        11253.96            5568.79
# 2023-01-01 02:00:00        19905.36            6172.02
# 2023-01-01 03:00:00        33653.62            8744.73
# 2023-01-01 04:00:00        32357.57           11872.15

# %%
monthly_df["total_deposit"] = monthly_df["deposit_amount"]
monthly_df["total_withdrawal"] = monthly_df["withdrawal_amount"]

monthly_df["net_flow"] = (
    monthly_df["total_deposit"] - monthly_df["total_withdrawal"]
)

# %%
monthly_df = monthly_df.reset_index()
monthly_df.rename(columns={"transaction_date": "date"}, inplace=True)

# %%
inflation = pd.read_csv("inflation.csv", skiprows=4)

# %%
inflation = inflation.melt(
    id_vars=["Country Name"],
    var_name="year",
    value_name="inflation_rate"
)

# %%
inflation = inflation[inflation["Country Name"] == "India"]

# %%
monthly_df.head()
# Out:
#                  date  deposit_amount  withdrawal_amount  total_deposit  \
# 0 2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1 2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2 2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3 2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4 2023-01-01 04:00:00        32357.57           11872.15       32357.57
#
#    total_withdrawal  net_flow
# 0           1828.63   6792.10
# 1           5568.79   5685.17
# 2           6172.02  13733.34
# 3           8744.73  24908.89
# 4          11872.15  20485.42

# %%
monthly_df.shape
# Out:
# (8783, 6)

# %%
year_cols = [col for col in inflation.columns if col.isdigit()]

# %%
inflation = inflation[["Country Name"] + year_cols]

# %%
inflation = inflation.melt(
    id_vars=["Country Name"],
    var_name="year",
    value_name="inflation_rate"
)

# %%
inflation["year"] = inflation["year"].astype(int)

# %%
inflation = inflation[inflation["Country Name"] == "India"]

# %%
inflation = inflation.dropna()

# %%
inflation = inflation[["year", "inflation_rate"]]

# %%
monthly_df["year"] = monthly_df["date"].dt.year

final_df = pd.merge(
    monthly_df,
    inflation[["year", "inflation_rate"]],
    on="year",
    how="left"
)

# %%
final_df.head()
# Out:
#                  date  deposit_amount  withdrawal_amount  total_deposit  \
# 0 2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1 2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2 2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3 2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4 2023-01-01 04:00:00        32357.57           11872.15       32357.57
#
#    total_withdrawal  net_flow  year  inflation_rate
# 0           1828.63   6792.10  2023             NaN
# 1           5568.79   5685.17  2023             NaN
# 2           6172.02  13733.34  2023             NaN
# 3           8744.73  24908.89  2023             NaN
# 4          11872.15  20485.42  2023             NaN

# %%
interest = pd.read_csv("interrest_rate.csv", skiprows=4)

# %%
interest.head()
# Out:
#                   Country Name Country Code             Indicator Name  \
# 0                        Aruba          ABW  Deposit interest rate (%)
# 1  Africa Eastern and Southern          AFE  Deposit interest rate (%)
# 2                  Afghanistan          AFG  Deposit interest rate (%)
# 3   Africa Western and Central          AFW  Deposit interest rate (%)
# 4                       Angola          AGO  Deposit interest rate (%)
#
#   Indicator Code  1960  1961  1962  1963  1964  1965  ...      2017      2018  \
# 0    FR.INR.DPST   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.600000  1.200000
# 1    FR.INR.DPST   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN
# 2    FR.INR.DPST   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN
# 3    FR.INR.DPST   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN
# 4    FR.INR.DPST   NaN   NaN   NaN   NaN   NaN   NaN  ...  6.342193  6.876657
#
# ...

# %%
year_cols = [col for col in interest.columns if col.isdigit()]

interest = interest[["Country Name"] + year_cols]

# %%
interest = interest.melt(
    id_vars=["Country Name"],
    var_name="year",
    value_name="interest_rate"
)

# %%
interest["year"] = interest["year"].astype(int)

# %%
interest = interest[interest["Country Name"] == "India"]

# %%
interest = interest.dropna()

# %%
interest = interest[["year", "interest_rate"]]

# %%
final_df = pd.merge(
    final_df,
    interest,
    on="year",
    how="left"
)

# %%
final_df
# Out:
#                     date  deposit_amount  withdrawal_amount  total_deposit  \
# 0    2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1    2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2    2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3    2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4    2023-01-01 04:00:00        32357.57           11872.15       32357.57
# ...                  ...             ...                ...            ...
# 8778 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 8779 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 8780 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 8781 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 8782 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
# ...

# %%
final_df = final_df.sort_values("date")

# %%
final_df["inflation_rate"] = final_df["inflation_rate"].ffill()
final_df["interest_rate"] = final_df["interest_rate"].ffill()

# %%
final_df
# Out:
#                     date  deposit_amount  withdrawal_amount  total_deposit  \
# 0    2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1    2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2    2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3    2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4    2023-01-01 04:00:00        32357.57           11872.15       32357.57
# ...                  ...             ...                ...            ...
# 8778 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 8779 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 8780 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 8781 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 8782 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
# ...

# %%
inflation.shape
# Out:
# (0, 2)

# %%
inflation = pd.read_csv("inflation.csv", skiprows=4)

# %%
inflation.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', '2025', 'Unnamed: 70'],
#       dtype='str')

# %%
inflation["Country Name"].unique()[:10]
# Out:
# <StringArray>
# [                      'Aruba', 'Africa Eastern and Southern',
#                  'Afghanistan',  'Africa Western and Central',
#                       'Angola',                     'Albania',
#                      'Andorra',                  'Arab World',
#         'United Arab Emirates',                   'Argentina']
# Length: 10, dtype: str

# %%
inflation[inflation["Country Name"].str.contains("India", case=False, na=False)].head()
# Out:
#     Country Name Country Code                         Indicator Name  \
# 109        India          IND  Inflation, consumer prices (annual %)
#
#      Indicator Code      1960      1961      1962      1963       1964  \
# 109  FP.CPI.TOTL.ZG  1.779878  1.695213  3.632215  2.946161  13.355261
#
#          1965  ...      2017      2018      2019      2020      2021  \
# 109  9.474759  ...  3.328173  3.938826  3.729506  6.623437  5.131407
#
#          2022      2023      2024  2025  Unnamed: 70
# 109  6.699034  5.649143  4.953036   NaN          NaN
#
# [1 rows x 71 columns]

# %%
inflation.shape
# Out:
# (266, 71)

# %%
inflation = inflation[
    inflation["Country Name"].str.contains("India", case=False, na=False)
]

# %%
inflation.shape
# Out:
# (1, 71)

# %%
year_cols = [col for col in inflation.columns if col.isdigit()]

inflation = inflation[["Country Name"] + year_cols]

# %%
inflation = inflation.melt(
    id_vars=["Country Name"],
    var_name="year",
    value_name="inflation_rate"
)

# %%
inflation["year"] = inflation["year"].astype(int)

inflation = inflation.dropna()

inflation = inflation[["year", "inflation_rate"]]

# %%
inflation.head()
# Out:
#    year  inflation_rate
# 0  1960        1.779878
# 1  1961        1.695213
# 2  1962        3.632215
# 3  1963        2.946161
# 4  1964       13.355261

# %%
final_df["year"] = final_df["date"].dt.year

# %%
final_df
# Out:
#                     date  deposit_amount  withdrawal_amount  total_deposit  \
# 0    2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1    2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2    2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3    2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4    2023-01-01 04:00:00        32357.57           11872.15       32357.57
# ...                  ...             ...                ...            ...
# 8778 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 8779 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 8780 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 8781 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 8782 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
# ...

# %%
final_df["year"] = final_df["date"].dt.year

# %%
final_df = pd.merge(
    final_df,
    inflation,
    on="year",
    how="left"
)

# %%
final_df = pd.merge(
    final_df,
    interest,
    on="year",
    how="left"
)

# %%
final_df
# Out:
#                     date  deposit_amount  withdrawal_amount  total_deposit  \
# 0    2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1    2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2    2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3    2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4    2023-01-01 04:00:00        32357.57           11872.15       32357.57
# ...                  ...             ...                ...            ...
# 8778 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 8779 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 8780 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 8781 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 8782 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
# ...

# %%
interest = pd.read_csv("interrest_rate.csv", skiprows=4)

interest = interest[
    interest["Country Name"].str.contains("India", case=False, na=False)
]

year_cols = [col for col in interest.columns if col.isdigit()]

interest = interest[["Country Name"] + year_cols]

interest = interest.melt(
    id_vars=["Country Name"],
    var_name="year",
    value_name="interest_rate"
)

interest["year"] = interest["year"].astype(int)

interest = interest.dropna()

interest = interest[["year", "interest_rate"]]

# %%
final_df = pd.merge(
    final_df,
    interest,
    on="year",
    how="left"
)

# %%
final_df
# Out:
#                     date  deposit_amount  withdrawal_amount  total_deposit  \
# 0    2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1    2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2    2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3    2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4    2023-01-01 04:00:00        32357.57           11872.15       32357.57
# ...                  ...             ...                ...            ...
# 8778 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 8779 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 8780 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 8781 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 8782 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
# ...

# %%
final_df = final_df.drop(columns=[
    "inflation_rate_x",
    "interest_rate_x",
    "interest_rate_y"
])

# %%
final_df = final_df.rename(columns={
    "inflation_rate_y": "inflation_rate"
})

# %%
interest = pd.read_csv("interrest_rate.csv", skiprows=4)

interest = interest[
    interest["Country Name"].str.contains("India", case=False, na=False)
]

year_cols = [col for col in interest.columns if col.isdigit()]

interest = interest[["Country Name"] + year_cols]

interest = interest.melt(
    id_vars=["Country Name"],
    var_name="year",
    value_name="interest_rate"
)

interest["year"] = interest["year"].astype(int)

interest = interest.dropna()

interest = interest[["year", "interest_rate"]]

# %%
final_df = pd.merge(
    final_df,
    interest,
    on="year",
    how="left"
)

# %%
final_df
# Out:
#                     date  deposit_amount  withdrawal_amount  total_deposit  \
# 0    2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1    2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2    2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3    2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4    2023-01-01 04:00:00        32357.57           11872.15       32357.57
# ...                  ...             ...                ...            ...
# 8778 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 8779 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 8780 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 8781 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 8782 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
# ...

# %%
interest.shape
# Out:
# (0, 2)

# %%
interest = pd.read_csv("interrest_rate.csv", skiprows=4)

# %%
interest["Country Name"].unique()[:20]
# Out:
# <StringArray>
# [                      'Aruba', 'Africa Eastern and Southern',
#                  'Afghanistan',  'Africa Western and Central',
#                       'Angola',                     'Albania',
#                      'Andorra',                  'Arab World',
#         'United Arab Emirates',                   'Argentina',
#                      'Armenia',              'American Samoa',
#          'Antigua and Barbuda',                   'Australia',
#                      'Austria',                  'Azerbaijan',
#                      'Burundi',                     'Belgium',
#                        'Benin',                'Burkina Faso']
# Length: 20, dtype: str

# %%
interest["Country Name"].str.contains("India", case=False, na=False).sum()
# Out:
# np.int64(1)

# %%
interest.shape
# Out:
# (266, 71)

# %%
interest = interest[
    interest["Country Name"].str.contains("India", case=False, na=False)
]

# %%
interest.shape
# Out:
# (1, 71)

# %%
year_cols = [col for col in interest.columns if col.isdigit()]

interest = interest[["Country Name"] + year_cols]

interest = interest.melt(
    id_vars=["Country Name"],
    var_name="year",
    value_name="interest_rate"
)

interest["year"] = interest["year"].astype(int)

interest = interest.dropna()

interest = interest[["year", "interest_rate"]]

# %%
interest.head()
# Out:
# Empty DataFrame
# Columns: [year, interest_rate]
# Index: []

# %%
interest = pd.read_csv("interrest_rate.csv", skiprows=4)


interest = interest[
    interest["Country Name"].str.contains("India", case=False, na=False)
]


year_cols = [col for col in interest.columns if col.isdigit()]
interest = interest[["Country Name"] + year_cols]


interest = interest.melt(
    id_vars=["Country Name"],
    var_name="year",
    value_name="interest_rate"
)


interest["year"] = interest["year"].astype(int)


interest = interest.dropna(subset=["interest_rate"])


interest = interest[["year", "interest_rate"]]

# %%
interest.shape
interest.tail()
# Out:
# Empty DataFrame
# Columns: [year, interest_rate]
# Index: []

# %%
final_df["interest_rate"] = 6.5 + (final_df["year"] - 2022) * 0.25

# %%
final_df
# Out:
#                     date  deposit_amount  withdrawal_amount  total_deposit  \
# 0    2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1    2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2    2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3    2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4    2023-01-01 04:00:00        32357.57           11872.15       32357.57
# ...                  ...             ...                ...            ...
# 8778 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 8779 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 8780 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 8781 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 8782 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
# ...

# %%
final_df = final_df.drop(columns=[
    
    "interest_rate_x",
    "interest_rate_y"
])

# %%
final_df
# Out:
#                     date  deposit_amount  withdrawal_amount  total_deposit  \
# 0    2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1    2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2    2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3    2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4    2023-01-01 04:00:00        32357.57           11872.15       32357.57
# ...                  ...             ...                ...            ...
# 8778 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 8779 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 8780 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 8781 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 8782 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
# ...

# %%
final_df["net_flow_lag1"] = final_df["net_flow"].shift(1)
final_df["net_flow_lag24"] = final_df["net_flow"].shift(24)

final_df["rolling_mean_24"] = final_df["net_flow"].rolling(24).mean()
final_df["rolling_std_24"] = final_df["net_flow"].rolling(24).std()

# %%
final_df
# Out:
#                     date  deposit_amount  withdrawal_amount  total_deposit  \
# 0    2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1    2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2    2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3    2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4    2023-01-01 04:00:00        32357.57           11872.15       32357.57
# ...                  ...             ...                ...            ...
# 8778 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 8779 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 8780 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 8781 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 8782 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
# ...

# %%
final_df.head(50)
# Out:
#                   date  deposit_amount  withdrawal_amount  total_deposit  \
# 0  2023-01-01 00:00:00         8620.73            1828.63        8620.73
# 1  2023-01-01 01:00:00        11253.96            5568.79       11253.96
# 2  2023-01-01 02:00:00        19905.36            6172.02       19905.36
# 3  2023-01-01 03:00:00        33653.62            8744.73       33653.62
# 4  2023-01-01 04:00:00        32357.57           11872.15       32357.57
# 5  2023-01-01 05:00:00        30066.96           15017.26       30066.96
# 6  2023-01-01 06:00:00        40185.20           14496.04       40185.20
# 7  2023-01-01 07:00:00        55088.08           20455.30       55088.08
# 8  2023-01-01 08:00:00        51136.55           27032.58       51136.55
# 9  2023-01-01 09:00:00        57103.46           31931.58       57103.46
# 10 2023-01-01 10:00:00        89526.53           31099.42       89526.53
# 11 2023-01-01 11:00:00        65360.59           26492.46       65360.59
# ...

# %%
final_df.isnull().sum()
# Out:
# date                  0
# deposit_amount        0
# withdrawal_amount     0
# total_deposit         0
# total_withdrawal      0
# net_flow              0
# year                  0
# inflation_rate        0
# interest_rate         0
# net_flow_lag1         1
# net_flow_lag24       24
# rolling_mean_24      23
# rolling_std_24       23
# dtype: int64

# %%
final_df = final_df.sort_values("date")
final_df = final_df.set_index("date")

# %%
final_df["hour"] = final_df.index.hour
final_df["day_of_week"] = final_df.index.dayofweek
final_df["is_weekend"] = final_df["day_of_week"].isin([5,6]).astype(int)

# %%
final_df["lag_1"] = final_df["net_flow"].shift(1)
final_df["lag_24"] = final_df["net_flow"].shift(24)

final_df["rolling_mean_24"] = final_df["net_flow"].rolling(24).mean()
final_df["rolling_std_24"] = final_df["net_flow"].rolling(24).std()

# %%
final_df["pct_change"] = final_df["net_flow"].pct_change()

# %%
final_df = final_df.dropna()

# %%
final_df
# Out:
#                      deposit_amount  withdrawal_amount  total_deposit  \
# date
# 2023-01-02 00:00:00       167002.70           55594.06      167002.70
# 2023-01-02 01:00:00       133305.54           49373.15      133305.54
# 2023-01-02 02:00:00       133366.97           65055.80      133366.97
# 2023-01-02 03:00:00       143536.41           62842.96      143536.41
# 2023-01-02 04:00:00       165567.14           55344.08      165567.14
# ...                             ...                ...            ...
# 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
#                      total_withdrawal   net_flow  year  inflation_rate  \
# date
# ...

# %%
final_df = final_df.drop(columns=["lag_1", "lag_24"])

# %%
final_df
# Out:
#                      deposit_amount  withdrawal_amount  total_deposit  \
# date
# 2023-01-02 00:00:00       167002.70           55594.06      167002.70
# 2023-01-02 01:00:00       133305.54           49373.15      133305.54
# 2023-01-02 02:00:00       133366.97           65055.80      133366.97
# 2023-01-02 03:00:00       143536.41           62842.96      143536.41
# 2023-01-02 04:00:00       165567.14           55344.08      165567.14
# ...                             ...                ...            ...
# 2024-01-01 18:00:00        30151.58           11959.83       30151.58
# 2024-01-01 19:00:00        20942.61            8862.07       20942.61
# 2024-01-01 20:00:00        22384.81            8801.94       22384.81
# 2024-01-01 21:00:00        19942.63            3929.51       19942.63
# 2024-01-01 22:00:00         3417.69            1936.16        3417.69
#
#                      total_withdrawal   net_flow  year  inflation_rate  \
# date
# ...

# %%
final_df.shape
final_df.info()
final_df.describe()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 8759 entries, 2023-01-02 00:00:00 to 2024-01-01 22:00:00
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   deposit_amount     8759 non-null   float64
#  1   withdrawal_amount  8759 non-null   float64
#  2   total_deposit      8759 non-null   float64
#  3   total_withdrawal   8759 non-null   float64
#  4   net_flow           8759 non-null   float64
#  5   year               8759 non-null   int32
#  6   inflation_rate     8759 non-null   float64
#  7   interest_rate      8759 non-null   float64
#  8   net_flow_lag1      8759 non-null   float64
#  9   net_flow_lag24     8759 non-null   float64
#  10  rolling_mean_24    8759 non-null   float64
#  11  rolling_std_24     8759 non-null   float64
#  12  hour               8759 non-null   int32
#  13  day_of_week        8759 non-null   int32
#  14  is_weekend         8759 non-null   int64
# ...

# %%
final_df.isnull().sum()
# Out:
# deposit_amount       0
# withdrawal_amount    0
# total_deposit        0
# total_withdrawal     0
# net_flow             0
# year                 0
# inflation_rate       0
# interest_rate        0
# net_flow_lag1        0
# net_flow_lag24       0
# rolling_mean_24      0
# rolling_std_24       0
# hour                 0
# day_of_week          0
# is_weekend           0
# pct_change           0
# dtype: int64

# %%
import matplotlib.pyplot as plt

final_df["net_flow"].hist(bins=50)
plt.title("Net Flow Distribution")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(final_df.index, final_df["net_flow"])
plt.title("Net Flow Over Time")
plt.show()

# %%
final_df.groupby("hour")["net_flow"].mean().plot()
plt.title("Average Net Flow by Hour")
plt.show()

# %%
final_df.groupby("day_of_week")["net_flow"].mean().plot()
plt.title("Net Flow by Day of Week")
plt.show()

# %%
final_df.groupby("is_weekend")["net_flow"].mean()
# Out:
# is_weekend
# 0    85330.156858
# 1    85358.449511
# Name: net_flow, dtype: float64

# %%
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib scikit-learn seaborn

import seaborn as sns

plt.figure(figsize=(14,8))
sns.heatmap(final_df.corr(), annot=True, cmap="coolwarm")
plt.tight_layout()
plt.show()
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\phuta\Downloads\ML_Project\ml_project_env\Scripts\python.exe -m pip install --upgrade pip

# %%
sns.boxplot(x=final_df["net_flow"])
# Out:
# <Axes: xlabel='net_flow'>

# %%
final_df[["net_flow", "inflation_rate", "interest_rate"]].corr()
# Out:
#                 net_flow  inflation_rate  interest_rate
# net_flow        1.000000        0.143165      -0.143165
# inflation_rate  0.143165        1.000000      -1.000000
# interest_rate  -0.143165       -1.000000       1.000000

# %%
final_df = final_df.drop(columns=[
    "total_deposit",
    "total_withdrawal"
])

# %%
final_df
# Out:
#                      deposit_amount  withdrawal_amount   net_flow  year  \
# date
# 2023-01-02 00:00:00       167002.70           55594.06  111408.64  2023
# 2023-01-02 01:00:00       133305.54           49373.15   83932.39  2023
# 2023-01-02 02:00:00       133366.97           65055.80   68311.17  2023
# 2023-01-02 03:00:00       143536.41           62842.96   80693.45  2023
# 2023-01-02 04:00:00       165567.14           55344.08  110223.06  2023
# ...                             ...                ...        ...   ...
# 2024-01-01 18:00:00        30151.58           11959.83   18191.75  2024
# 2024-01-01 19:00:00        20942.61            8862.07   12080.54  2024
# 2024-01-01 20:00:00        22384.81            8801.94   13582.87  2024
# 2024-01-01 21:00:00        19942.63            3929.51   16013.12  2024
# 2024-01-01 22:00:00         3417.69            1936.16    1481.53  2024
#
#                      inflation_rate  interest_rate  net_flow_lag1  \
# date
# ...

# %%
final_df["pct_change"] = final_df["pct_change"].replace([float("inf"), -float("inf")], 0)

# %%
final_df
# Out:
#                      deposit_amount  withdrawal_amount   net_flow  year  \
# date
# 2023-01-02 00:00:00       167002.70           55594.06  111408.64  2023
# 2023-01-02 01:00:00       133305.54           49373.15   83932.39  2023
# 2023-01-02 02:00:00       133366.97           65055.80   68311.17  2023
# 2023-01-02 03:00:00       143536.41           62842.96   80693.45  2023
# 2023-01-02 04:00:00       165567.14           55344.08  110223.06  2023
# ...                             ...                ...        ...   ...
# 2024-01-01 18:00:00        30151.58           11959.83   18191.75  2024
# 2024-01-01 19:00:00        20942.61            8862.07   12080.54  2024
# 2024-01-01 20:00:00        22384.81            8801.94   13582.87  2024
# 2024-01-01 21:00:00        19942.63            3929.51   16013.12  2024
# 2024-01-01 22:00:00         3417.69            1936.16    1481.53  2024
#
#                      inflation_rate  interest_rate  net_flow_lag1  \
# date
# ...

# %%
final_df.isnull().sum()
# Out:
# deposit_amount       0
# withdrawal_amount    0
# net_flow             0
# year                 0
# inflation_rate       0
# interest_rate        0
# net_flow_lag1        0
# net_flow_lag24       0
# rolling_mean_24      0
# rolling_std_24       0
# hour                 0
# day_of_week          0
# is_weekend           0
# pct_change           0
# dtype: int64

# %%
df_insights = final_df.copy()   
df_model = final_df.copy()

# %%
df_model
# Out:
#                      deposit_amount  withdrawal_amount   net_flow  year  \
# date
# 2023-01-02 00:00:00       167002.70           55594.06  111408.64  2023
# 2023-01-02 01:00:00       133305.54           49373.15   83932.39  2023
# 2023-01-02 02:00:00       133366.97           65055.80   68311.17  2023
# 2023-01-02 03:00:00       143536.41           62842.96   80693.45  2023
# 2023-01-02 04:00:00       165567.14           55344.08  110223.06  2023
# ...                             ...                ...        ...   ...
# 2024-01-01 18:00:00        30151.58           11959.83   18191.75  2024
# 2024-01-01 19:00:00        20942.61            8862.07   12080.54  2024
# 2024-01-01 20:00:00        22384.81            8801.94   13582.87  2024
# 2024-01-01 21:00:00        19942.63            3929.51   16013.12  2024
# 2024-01-01 22:00:00         3417.69            1936.16    1481.53  2024
#
#                      inflation_rate  interest_rate  net_flow_lag1  \
# date
# ...

# %%
df_model.columns
# Out:
# Index(['deposit_amount', 'withdrawal_amount', 'net_flow', 'year',
#        'inflation_rate', 'interest_rate', 'net_flow_lag1', 'net_flow_lag24',
#        'rolling_mean_24', 'rolling_std_24', 'hour', 'day_of_week',
#        'is_weekend', 'pct_change'],
#       dtype='str')

# %%
df_model = df_model.drop(columns=["year"])

# %%
df_model.isnull().sum()
# Out:
# deposit_amount       0
# withdrawal_amount    0
# net_flow             0
# inflation_rate       0
# interest_rate        0
# net_flow_lag1        0
# net_flow_lag24       0
# rolling_mean_24      0
# rolling_std_24       0
# hour                 0
# day_of_week          0
# is_weekend           0
# pct_change           0
# dtype: int64

# %%
features = [
    "net_flow",
    "deposit_amount",
    "withdrawal_amount",
    "net_flow_lag1",
    "net_flow_lag24",
    "rolling_mean_24",
    "rolling_std_24",
    "pct_change",
    "hour",
    "day_of_week",
    "is_weekend",
    "inflation_rate",
    "interest_rate"
]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_model[features] = scaler.fit_transform(df_model[features])

# %%
df_model
# Out:
#                      deposit_amount  withdrawal_amount  net_flow  \
# date
# 2023-01-02 00:00:00        1.691533          -0.449184  1.803498
# 2023-01-02 01:00:00       -0.697036          -1.715413 -0.097252
# 2023-01-02 02:00:00       -0.692682           1.476695 -1.177896
# 2023-01-02 03:00:00        0.028163           1.026285 -0.321316
# 2023-01-02 04:00:00        1.589776          -0.500066  1.721482
# ...                             ...                ...       ...
# 2024-01-01 18:00:00       -8.008939          -9.330668 -4.645055
# 2024-01-01 19:00:00       -8.661703          -9.961198 -5.067816
# 2024-01-01 20:00:00       -8.559474          -9.973438 -4.963888
# 2024-01-01 21:00:00       -8.732585         -10.965191 -4.795768
# 2024-01-01 22:00:00       -9.903928         -11.370926 -5.801034
#
#                      inflation_rate  interest_rate  net_flow_lag1  \
# date
# 2023-01-02 00:00:00        0.051311      -0.051311       0.370510
# ...

# %%
X = df_model.copy()

split = int(len(X) * 0.8)

X_train = X.iloc[:split]
X_test = X.iloc[split:]

# %%
X_train
# Out:
#                      deposit_amount  withdrawal_amount  net_flow  \
# date
# 2023-01-02 00:00:00        1.691533          -0.449184  1.803498
# 2023-01-02 01:00:00       -0.697036          -1.715413 -0.097252
# 2023-01-02 02:00:00       -0.692682           1.476695 -1.177896
# 2023-01-02 03:00:00        0.028163           1.026285 -0.321316
# 2023-01-02 04:00:00        1.589776          -0.500066  1.721482
# ...                             ...                ...       ...
# 2023-10-20 18:00:00        0.362565           1.432274 -0.132942
# 2023-10-20 19:00:00        0.610970          -1.136772  0.982622
# 2023-10-20 20:00:00       -0.174927           0.241982 -0.252960
# 2023-10-20 21:00:00       -0.050574          -0.927688  0.265934
# 2023-10-20 22:00:00        0.618914          -0.772736  0.866650
#
#                      inflation_rate  interest_rate  net_flow_lag1  \
# date
# 2023-01-02 00:00:00        0.051311      -0.051311       0.370510
# ...

# %%
X_test
# Out:
#                      deposit_amount  withdrawal_amount  net_flow  \
# date
# 2023-10-20 23:00:00       -0.489296          -0.317205 -0.369716
# 2023-10-21 00:00:00        1.846905          -1.580638  2.339676
# 2023-10-21 01:00:00        0.054454          -0.809040  0.328110
# 2023-10-21 02:00:00        0.106697           0.483603 -0.060231
# 2023-10-21 03:00:00        0.372008          -0.424358  0.507283
# ...                             ...                ...       ...
# 2024-01-01 18:00:00       -8.008939          -9.330668 -4.645055
# 2024-01-01 19:00:00       -8.661703          -9.961198 -5.067816
# 2024-01-01 20:00:00       -8.559474          -9.973438 -4.963888
# 2024-01-01 21:00:00       -8.732585         -10.965191 -4.795768
# 2024-01-01 22:00:00       -9.903928         -11.370926 -5.801034
#
#                      inflation_rate  interest_rate  net_flow_lag1  \
# date
# 2023-10-20 23:00:00        0.051311      -0.051311       0.867607
# ...

# %%
from sklearn.ensemble import IsolationForest

model = IsolationForest(
    n_estimators=100,      
    contamination=0.01,    
    random_state=42
)

model.fit(X_train)
# Out:
# IsolationForest(contamination=0.01, random_state=42)

# %%
features = [
    "deposit_amount",
    "withdrawal_amount",
    "net_flow",
    "net_flow_lag1",
    "net_flow_lag24",
    "rolling_mean_24",
    "rolling_std_24",
    "pct_change",
    "hour",
    "day_of_week",
    "is_weekend",
    "inflation_rate",
    "interest_rate"
]

# %%
X_train = df_model.iloc[:split][features]
X_test = df_model.iloc[split:][features]
model.fit(X_train)
# Out:
# IsolationForest(contamination=0.01, random_state=42)

# %%
X_full = df_model[features]

df_model["anomaly"] = model.predict(X_full)
X_test["anomaly"] = model.predict(X_test)

# %%
print(X_train.columns)
print(df_model[features].columns)
# Out:
# Index(['deposit_amount', 'withdrawal_amount', 'net_flow', 'net_flow_lag1',
#        'net_flow_lag24', 'rolling_mean_24', 'rolling_std_24', 'pct_change',
#        'hour', 'day_of_week', 'is_weekend', 'inflation_rate', 'interest_rate'],
#       dtype='str')
# Index(['deposit_amount', 'withdrawal_amount', 'net_flow', 'net_flow_lag1',
#        'net_flow_lag24', 'rolling_mean_24', 'rolling_std_24', 'pct_change',
#        'hour', 'day_of_week', 'is_weekend', 'inflation_rate', 'interest_rate'],
#       dtype='str')

# %%
df_model[["anomaly"]]
# Out:
#                      anomaly
# date
# 2023-01-02 00:00:00       -1
# 2023-01-02 01:00:00       -1
# 2023-01-02 02:00:00       -1
# 2023-01-02 03:00:00       -1
# 2023-01-02 04:00:00       -1
# ...                      ...
# 2024-01-01 18:00:00       -1
# 2024-01-01 19:00:00       -1
# 2024-01-01 20:00:00       -1
# 2024-01-01 21:00:00       -1
# 2024-01-01 22:00:00       -1
#
# [8759 rows x 1 columns]

# %%
df_model["anomaly"].value_counts()
# Out:
# anomaly
#  1    8659
# -1     100
# Name: count, dtype: int64

# %%
X_test[["anomaly"]]
# Out:
#                      anomaly
# date
# 2023-10-20 23:00:00        1
# 2023-10-21 00:00:00        1
# 2023-10-21 01:00:00        1
# 2023-10-21 02:00:00        1
# 2023-10-21 03:00:00        1
# ...                      ...
# 2024-01-01 18:00:00       -1
# 2024-01-01 19:00:00       -1
# 2024-01-01 20:00:00       -1
# 2024-01-01 21:00:00       -1
# 2024-01-01 22:00:00       -1
#
# [1752 rows x 1 columns]

# %%
X_test["anomaly"].value_counts()
# Out:
# anomaly
#  1    1723
# -1      29
# Name: count, dtype: int64

# %%
df_model["anomaly"] = df_model["anomaly"].map({1: 0, -1: 1})

# %%
df_model["anomaly"].value_counts()
# Out:
# anomaly
# 0    8659
# 1     100
# Name: count, dtype: int64

# %%
df_model.describe()
# Out:
#        deposit_amount  withdrawal_amount      net_flow  inflation_rate  \
# count    8.759000e+03       8.759000e+03  8.759000e+03    8.759000e+03
# mean    -7.511846e-16       1.812253e-15 -1.344182e-15    2.518659e-14
# std      1.000057e+00       1.000057e+00  1.000057e+00    1.000057e+00
# min     -9.903928e+00      -1.137093e+01 -5.801034e+00   -1.948913e+01
# 25%     -6.483969e-01      -6.204759e-01 -6.723024e-01    5.131066e-02
# 50%      1.692888e-03      -3.415534e-04  5.792322e-03    5.131066e-02
# 75%      6.586675e-01       6.347034e-01  6.603444e-01    5.131066e-02
# max      4.168096e+00       3.727202e+00  4.103449e+00    5.131066e-02
#
#        interest_rate  net_flow_lag1  net_flow_lag24  rolling_mean_24  \
# count   8.759000e+03   8.759000e+03    8.759000e+03     8.759000e+03
# mean    4.578494e-15   8.606985e-16    3.082615e-17    -1.437472e-15
# std     1.000057e+00   1.000057e+00    1.000057e+00     1.000057e+00
# ...

# %%
df_model[df_model["anomaly"] == 1].sort_values(by="net_flow")
# Out:
#                      deposit_amount  withdrawal_amount  net_flow  \
# date
# 2024-01-01 22:00:00       -9.903928         -11.370926 -5.801034
# 2024-01-01 19:00:00       -8.661703          -9.961198 -5.067816
# 2024-01-01 20:00:00       -8.559474          -9.973438 -4.963888
# 2024-01-01 21:00:00       -8.732585         -10.965191 -4.795768
# 2024-01-01 16:00:00       -7.730537          -8.423051 -4.681820
# ...                             ...                ...       ...
# 2023-09-18 15:00:00        2.898689          -1.296131  3.269459
# 2023-09-05 10:00:00        2.976734          -2.253602  3.671039
# 2023-03-14 21:00:00        3.390095          -1.144892  3.697640
# 2023-09-18 17:00:00        3.896884          -0.215526  3.876375
# 2023-06-08 19:00:00        3.909017          -0.848810  4.103449
#
#                      inflation_rate  interest_rate  net_flow_lag1  \
# date
# 2024-01-01 22:00:00      -19.489127      19.489127      -4.805677
# ...

# %%
df_model
# Out:
#                      deposit_amount  withdrawal_amount  net_flow  \
# date
# 2023-01-02 00:00:00        1.691533          -0.449184  1.803498
# 2023-01-02 01:00:00       -0.697036          -1.715413 -0.097252
# 2023-01-02 02:00:00       -0.692682           1.476695 -1.177896
# 2023-01-02 03:00:00        0.028163           1.026285 -0.321316
# 2023-01-02 04:00:00        1.589776          -0.500066  1.721482
# ...                             ...                ...       ...
# 2024-01-01 18:00:00       -8.008939          -9.330668 -4.645055
# 2024-01-01 19:00:00       -8.661703          -9.961198 -5.067816
# 2024-01-01 20:00:00       -8.559474          -9.973438 -4.963888
# 2024-01-01 21:00:00       -8.732585         -10.965191 -4.795768
# 2024-01-01 22:00:00       -9.903928         -11.370926 -5.801034
#
#                      inflation_rate  interest_rate  net_flow_lag1  \
# date
# 2023-01-02 00:00:00        0.051311      -0.051311       0.370510
# ...

# %%
df_model[df_model["anomaly"] == 1]["net_flow"].describe()
# Out:
# count    100.000000
# mean      -0.883905
# std        2.513987
# min       -5.801034
# 25%       -2.721668
# 50%       -1.948054
# 75%        1.423976
# max        4.103449
# Name: net_flow, dtype: float64

# %%
df_model[df_model["anomaly"] == 0]["net_flow"].describe()
# Out:
# count    8659.000000
# mean        0.010208
# std         0.964505
# min        -3.451369
# 25%        -0.659268
# 50%         0.007925
# 75%         0.656669
# max         4.042115
# Name: net_flow, dtype: float64

# %%
df_model[df_model["anomaly"] == 1][["net_flow","pct_change","hour"]]
# Out:
#                      net_flow  pct_change      hour
# date
# 2023-01-02 00:00:00  1.803498    0.783068 -1.661302
# 2023-01-02 01:00:00 -0.097252   -1.087474 -1.516825
# 2023-01-02 02:00:00 -1.177896   -0.849204 -1.372347
# 2023-01-02 03:00:00 -0.321316    0.597450 -1.227869
# 2023-01-02 04:00:00  1.721482    1.324696 -1.083392
# ...                       ...         ...       ...
# 2024-01-01 18:00:00 -4.645055   -1.016793  0.939294
# 2024-01-01 19:00:00 -5.067816   -1.439145  1.083771
# 2024-01-01 20:00:00 -4.963888    0.373378  1.228249
# 2024-01-01 21:00:00 -4.795768    0.588225  1.372726
# 2024-01-01 22:00:00 -5.801034   -3.689761  1.517204
#
# [100 rows x 3 columns]

# %%
df_model["score"] = model.decision_function(df_model[features])

# %%
df_model
# Out:
#                      deposit_amount  withdrawal_amount  net_flow  \
# date
# 2023-01-02 00:00:00        1.691533          -0.449184  1.803498
# 2023-01-02 01:00:00       -0.697036          -1.715413 -0.097252
# 2023-01-02 02:00:00       -0.692682           1.476695 -1.177896
# 2023-01-02 03:00:00        0.028163           1.026285 -0.321316
# 2023-01-02 04:00:00        1.589776          -0.500066  1.721482
# ...                             ...                ...       ...
# 2024-01-01 18:00:00       -8.008939          -9.330668 -4.645055
# 2024-01-01 19:00:00       -8.661703          -9.961198 -5.067816
# 2024-01-01 20:00:00       -8.559474          -9.973438 -4.963888
# 2024-01-01 21:00:00       -8.732585         -10.965191 -4.795768
# 2024-01-01 22:00:00       -9.903928         -11.370926 -5.801034
#
#                      inflation_rate  interest_rate  net_flow_lag1  \
# date
# 2023-01-02 00:00:00        0.051311      -0.051311       0.370510
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,6))

plt.plot(df_model.index, df_model["net_flow"], label="Net Flow")

plt.scatter(
    df_model[df_model["anomaly"] == 1].index,
    df_model[df_model["anomaly"] == 1]["net_flow"],
    color="red",
    label="Anomaly"
)

plt.legend()
plt.title("Anomaly Detection in Financial Transactions")
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.hist(df_model["score"], bins=50)

plt.title("Anomaly Score Distribution")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# %%
top_anomalies = df_model.sort_values(by="score").head(20)

plt.figure(figsize=(12,5))
plt.bar(range(len(top_anomalies)), top_anomalies["score"])
plt.title("Top 20 Most Severe Anomalies")
plt.xlabel("Index")
plt.ylabel("Score")
plt.show()

# %%
hour_anomaly = df_model.groupby("hour")["anomaly"].sum()

plt.figure(figsize=(10,5))
hour_anomaly.plot(kind="bar")

plt.title("Anomalies by Hour")
plt.xlabel("Hour")
plt.ylabel("Number of Anomalies")
plt.show()

# %%
dow_anomaly = df_model.groupby("day_of_week")["anomaly"].sum()

plt.figure(figsize=(10,5))
dow_anomaly.plot(kind="bar")

plt.title("Anomalies by Day of Week")
plt.xlabel("Day")
plt.ylabel("Anomaly Count")
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.scatter(df_model["net_flow"], df_model["pct_change"], alpha=0.3)

plt.scatter(
    df_model[df_model["anomaly"] == 1]["net_flow"],
    df_model[df_model["anomaly"] == 1]["pct_change"],
    color="red"
)

plt.title("Net Flow vs Percentage Change")
plt.xlabel("Net Flow")
plt.ylabel("Pct Change")
plt.show()

# %%
plt.figure(figsize=(15,6))

plt.plot(df_model.index, df_model["rolling_mean_24"], label="Rolling Mean")

plt.scatter(
    df_model[df_model["anomaly"] == 1].index,
    df_model[df_model["anomaly"] == 1]["rolling_mean_24"],
    color="red"
)

plt.title("Rolling Mean with Anomalies")
plt.legend()
plt.show()

# %%
df_model.to_csv("processed_data
