# %%
# !pip install ipykernel

# %%
# !python -m ipykernel install --user --name=ml_project_env
# Out:
# Installed kernelspec ml_project_env in C:\Users\phuta\AppData\Roaming\jupyter\kernels\ml_project_env

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\phuta\anaconda3\python.exe
